# %%
from sklearn.datasets import load_boston
import pandas as pd
from sklearn.linear_model import LinearRegression;
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler;
from sklearn.model_selection import GridSearchCV;

#basic

# def ShowData(x1):
#     x=pd.DataFrame(x1)
#     print(x)
x,y=load_boston(return_X_y=True)
y.reshape(y.shape[0],1)
# x=StandardScaler().fit(x);
# y=StandardScaler().fit(y);
pipe=Pipeline([
          ("sacle",StandardScaler()),
          ("model",KNeighborsRegressor(n_neighbors=1))
          
          ])

pipe.get_params()
test=GridSearchCV(estimator=pipe,param_grid={'model__n_neighbors':[1]},cv=3)
# x
# ShowData(x)
# ans=cross_validate(pipe,x,y)
# pd.DataFrame(x)
# test.fit(x,y)
# pd.DataFrame(test.cv_results_)

# %%
mod=test.fit(x,y);
ans=mod.predict(x)
import matplotlib.pyplot as plt
plt.scatter(ans,y)

# %%
print(load_boston()['DESCR'])

# %%
# Play With Data

import numpy as np;

data=pd.read_csv('data.csv')
# data['x']
x=data[['x','y']
y=data['z']
# plt.scatter(x,y)
sc=StandardScaler();
# x.reshape(-1, 1)
# y.reshape(-1,1);

x=sc.fit_transform(x+y)
plt.scatter(x,y)
# Out:
#   File "<ipython-input-12-31a0a19d6387>", line 8
#     y=data['z']
#     ^
# SyntaxError: invalid syntax

# %%
[[1,2]],[[2]]
# Out:
# ([[1, 2]], [[2]])
